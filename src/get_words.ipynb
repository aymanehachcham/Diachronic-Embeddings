# %%
import pandas as pd

# %%
df_80 = pd.read_csv('data_csv/news_1980.csv')
df_85 = pd.read_csv('data_csv/news_1985.csv')
df_90 = pd.read_csv('data_csv/news_1990.csv')
df_95 = pd.read_csv('data_csv/news_1995.csv')
df_00 = pd.read_csv('data_csv/news_2000.csv')
df_05 = pd.read_csv('data_csv/news_2005.csv')
df_10 = pd.read_csv('data_csv/news_2010.csv')

# %%
df_15 = pd.read_csv('data_csv/news_2015.csv')

# %%
all_words = []

all_docs = pd.concat([df_80['text'], df_85['text'], df_90['text'], df_95['text'], df_00['text'], df_05['text'], df_10['text'], df_15['text']])

for doc in all_docs:
    words = str(doc).split()

    all_words += words

# %% [markdown]
# # Getting the list of target words:

# %%
from collections import Counter

# %%
all_words = list(filter(lambda x: len(x) > 4, all_words))

# %%
def most_common_tokens(n, words):

    counter = Counter(words)

    return counter.most_common(n)

# %%
most_common_words = most_common_tokens(200, all_words)

# %%
most_common_words
# Out:
# [('would', 548260),
#  ('state', 402612),
#  ('first', 329554),
#  ('people', 298390),
#  ('company', 287444),
#  ('percent', 253710),
#  ('million', 249214),
#  ('could', 247584),
#  ('american', 243870),
#  ('three', 222926),
#  ('president', 215420),
#  ('united', 189491),
#  ('official', 179824),
#  ('school', 173529),
#  ('government', 167426),
#  ('month', 165121),
#  ('house', 162014),
#  ('street', 159705),
#  ('group', 158336),
#  ('right', 157369),
#  ("''the", 157308),
#  ('still', 155802),
#  ('point', 152080),
#  ('since', 151131),
#  ('world', 147988),
#  ('second', 143944),
#  ('today', 140065),
#  ('another', 139936),
#  ('program', 132401),
#  ('public', 130026),
#  ('national', 129026),
#  ('business', 127887),
#  ('member', 126644),
#  ('child', 126342),
#  ('family', 123881),
#  ('country', 123748),
#  ('service', 122381),
#  ('woman', 119761),
#  ('market', 119440),
#  ('center', 119421),
#  ('think', 118960),
#  ('going', 118384),
#  ('thing', 116791),
#  ('place', 116139),
#  ('called', 114466),
#  ('court', 113363),
#  ('university', 111550),
#  ('federal', 111509),
#  ('white', 109222),
#  ('director', 107943),
#  ('might', 107532),
#  ('including', 106949),
#  ('season', 106907),
#  ('price', 106789),
#  ('money', 106712),
#  ('little', 104177),
#  ('among', 102744),
#  ('problem', 102323),
#  ('never', 101899),
#  ('around', 101539),
#  ('office', 101443),
#  ('system', 100570),
#  ('party', 99557),
#  ('police', 99246),
#  ('several', 98477),
#  ('night', 98029),
#  ('executive', 98000),
#  ('former', 97854),
#  ('number', 95232),
#  ('billion', 93978),
#  ('issue', 93912),
#  ('department', 92065),
#  ('building', 91750),
#  ('share', 91468),
#  ('political', 91049),
#  ('without', 90467),
#  ('republican', 89780),
#  ('found', 89354),
#  ('yesterday', 89076),
#  ('change', 88938),
#  ('black', 88662),
#  ('student', 88315),
#  ('report', 87070),
#  ('every', 86757),
#  ('leader', 86463),
#  ('general', 86322),
#  ('player', 85510),
#  ('later', 83332),
#  ('early', 83116),
#  ('major', 82638),
#  ('third', 82609),
#  ('though', 81774),
#  ('music', 81712),
#  ('according', 81374),
#  ('small', 81097),
#  ('security', 79676),
#  ('great', 79154),
#  ('chief', 78942),
#  ('often', 78528),
#  ('board', 77851),
#  ('young', 77500),
#  ('whether', 76286),
#  ('power', 76156),
#  ('question', 76081),
#  ('recent', 75782),
#  ('washington', 75610),
#  ('whose', 75178),
#  ('force', 74970),
#  ('interest', 74947),
#  ('become', 74614),
#  ('least', 74331),
#  ('better', 74220),
#  ('union', 74052),
#  ('asked', 73938),
#  ('story', 73794),
#  ('something', 73736),
#  ('record', 73579),
#  ('added', 73254),
#  ('minute', 73209),
#  ('stock', 72589),
#  ('south', 72146),
#  ('known', 72023),
#  ('college', 71265),
#  ('began', 70672),
#  ('officer', 70587),
#  ('agency', 69819),
#  ('health', 69234),
#  ('based', 69104),
#  ('international', 67893),
#  ('policy', 67887),
#  ('decision', 67871),
#  ('industry', 67835),
#  ('friend', 67434),
#  ('large', 67202),
#  ('effort', 67129),
#  ('making', 67050),
#  ('result', 66727),
#  ('enough', 66366),
#  ('start', 65783),
#  ('others', 65647),
#  ('always', 65582),
#  ('support', 65553),
#  ('really', 65313),
#  ('almost', 64960),
#  ('charge', 64671),
#  ('sunday', 64446),
#  ('campaign', 64347),
#  ('theater', 64260),
#  ('father', 64132),
#  ('water', 63194),
#  ('administration', 62621),
#  ('however', 62616),
#  ('lawyer', 62228),
#  ('although', 62199),
#  ('friday', 62178),
#  ('television', 62039),
#  ('local', 61944),
#  ('already', 61885),
#  ('control', 61152),
#  ('meeting', 61111),
#  ('quarter', 60945),
#  ('military', 60943),
#  ('expected', 60826),
#  ('death', 60650),
#  ('study', 60561),
#  ('history', 59569),
#  ('increase', 59368),
#  ('north', 59332),
#  ('course', 59282),
#  ('information', 59227),
#  ('along', 59004),
#  ('offer', 58533),
#  ('committee', 58414),
#  ('community', 58167),
#  ('series', 58110),
#  ('chairman', 57835),
#  ('judge', 57514),
#  ('nation', 57462),
#  ('manhattan', 57361),
#  ('different', 57237),
#  ('level', 56680),
#  ('march', 56656),
#  ('economic', 56497),
#  ('project', 56429),
#  ('thought', 56289),
#  ('museum', 55848),
#  ('working', 55662),
#  ('financial', 55530),
#  ("that's", 55491),
#  ('saturday', 55296),
#  ('trying', 55274),
#  ('close', 55232),
#  ('county', 55153),
#  ('important', 54929),
#  ('avenue', 54908),
#  ('budget', 54870),
#  ('worker', 54591),
#  ('given', 54568),
#  ('mother', 54542),
#  ('democrat', 53196)]

# %%
most_comon = []
for i in range(200):
    most_comon.append(most_common_words[i][0])

# %%
most_comon
# Out:
# ['would',
#  'state',
#  'first',
#  'people',
#  'company',
#  'percent',
#  'million',
#  'could',
#  'american',
#  'three',
#  'president',
#  'united',
#  'official',
#  'school',
#  'government',
#  'month',
#  'house',
#  'street',
#  'group',
#  'right',
#  "''the",
#  'still',
#  'point',
#  'since',
#  'world',
#  'second',
#  'today',
#  'another',
#  'program',
#  'public',
#  'national',
#  'business',
#  'member',
#  'child',
#  'family',
#  'country',
#  'service',
#  'woman',
#  'market',
#  'center',
#  'think',
#  'going',
#  'thing',
#  'place',
#  'called',
#  'court',
#  'university',
#  'federal',
#  'white',
#  'director',
#  'might',
#  'including',
#  'season',
#  'price',
#  'money',
#  'little',
#  'among',
#  'problem',
#  'never',
#  'around',
#  'office',
#  'system',
#  'party',
#  'police',
#  'several',
#  'night',
#  'executive',
#  'former',
#  'number',
#  'billion',
#  'issue',
#  'department',
#  'building',
#  'share',
#  'political',
#  'without',
#  'republican',
#  'found',
#  'yesterday',
#  'change',
#  'black',
#  'student',
#  'report',
#  'every',
#  'leader',
#  'general',
#  'player',
#  'later',
#  'early',
#  'major',
#  'third',
#  'though',
#  'music',
#  'according',
#  'small',
#  'security',
#  'great',
#  'chief',
#  'often',
#  'board',
#  'young',
#  'whether',
#  'power',
#  'question',
#  'recent',
#  'washington',
#  'whose',
#  'force',
#  'interest',
#  'become',
#  'least',
#  'better',
#  'union',
#  'asked',
#  'story',
#  'something',
#  'record',
#  'added',
#  'minute',
#  'stock',
#  'south',
#  'known',
#  'college',
#  'began',
#  'officer',
#  'agency',
#  'health',
#  'based',
#  'international',
#  'policy',
#  'decision',
#  'industry',
#  'friend',
#  'large',
#  'effort',
#  'making',
#  'result',
#  'enough',
#  'start',
#  'others',
#  'always',
#  'support',
#  'really',
#  'almost',
#  'charge',
#  'sunday',
#  'campaign',
#  'theater',
#  'father',
#  'water',
#  'administration',
#  'however',
#  'lawyer',
#  'although',
#  'friday',
#  'television',
#  'local',
#  'already',
#  'control',
#  'meeting',
#  'quarter',
#  'military',
#  'expected',
#  'death',
#  'study',
#  'history',
#  'increase',
#  'north',
#  'course',
#  'information',
#  'along',
#  'offer',
#  'committee',
#  'community',
#  'series',
#  'chairman',
#  'judge',
#  'nation',
#  'manhattan',
#  'different',
#  'level',
#  'march',
#  'economic',
#  'project',
#  'thought',
#  'museum',
#  'working',
#  'financial',
#  "that's",
#  'saturday',
#  'trying',
#  'close',
#  'county',
#  'important',
#  'avenue',
#  'budget',
#  'worker',
#  'given',
#  'mother',
#  'democrat']

# %%
text_80 = ''
for i in df_80['text']:
    text_80 += str(i) + ' '

text_85 = ''
for i in df_85['text']:
    text_85 += str(i) + ' '

text_90 = ''
for i in df_90['text']:
    text_90 += str(i) + ' '

text_95 = ''
for i in df_95['text']:
    text_95 += str(i) + ' '

text_00 = ''
for i in df_00['text']:
    text_00 += str(i) + ' '

text_05 = ''
for i in df_05['text']:
    text_05 += str(i) + ' '

text_10 = ''
for i in df_10['text']:
    text_10 += str(i) + ' '

text_15 = ''
for i in df_15['text']:
    text_15 += str(i) + ' '

# %%
texts = [text_80, text_85, text_90, text_95, text_00, text_05, text_10, text_15]

# %%
for i in range(len(texts)):
    words = texts[i].strip().split()

    print(words.count('virus'))
# Out:
# 380
# 571
# 1184
# 1356
# 1604
# 916
# 495
# 644

# %%
most_comon.remove("important")

# %%
most_comon
# Out:
# ['state',
#  'people',
#  'company',
#  'percent',
#  'million',
#  'american',
#  'president',
#  'united',
#  'official',
#  'school',
#  'government',
#  'house',
#  'street',
#  'group',
#  'right',
#  'point',
#  'since',
#  'world',
#  'second',
#  'program',
#  'public',
#  'national',
#  'business',
#  'member',
#  'child',
#  'family',
#  'country',
#  'service',
#  'woman',
#  'market',
#  'center',
#  'think',
#  'going',
#  'thing',
#  'place',
#  'called',
#  'court',
#  'university',
#  'federal',
#  'white',
#  'director',
#  'might',
#  'including',
#  'season',
#  'price',
#  'money',
#  'little',
#  'among',
#  'problem',
#  'never',
#  'around',
#  'office',
#  'system',
#  'party',
#  'police',
#  'several',
#  'night',
#  'executive',
#  'former',
#  'number',
#  'billion',
#  'issue',
#  'department',
#  'building',
#  'share',
#  'political',
#  'without',
#  'republican',
#  'found',
#  'yesterday',
#  'change',
#  'black',
#  'student',
#  'report',
#  'every',
#  'leader',
#  'general',
#  'player',
#  'later',
#  'early',
#  'major',
#  'third',
#  'though',
#  'music',
#  'according',
#  'small',
#  'security',
#  'great',
#  'chief',
#  'often',
#  'board',
#  'young',
#  'whether',
#  'power',
#  'question',
#  'recent',
#  'washington',
#  'whose',
#  'force',
#  'interest',
#  'become',
#  'least',
#  'better',
#  'union',
#  'asked',
#  'story',
#  'something',
#  'record',
#  'added',
#  'minute',
#  'stock',
#  'south',
#  'known',
#  'college',
#  'began',
#  'officer',
#  'agency',
#  'health',
#  'based',
#  'international',
#  'policy',
#  'decision',
#  'industry',
#  'friend',
#  'large',
#  'effort',
#  'making',
#  'result',
#  'enough',
#  'start',
#  'others',
#  'always',
#  'support',
#  'really',
#  'almost',
#  'charge',
#  'sunday',
#  'campaign',
#  'theater',
#  'father',
#  'water',
#  'administration',
#  'however',
#  'lawyer',
#  'although',
#  'friday',
#  'television',
#  'local',
#  'already',
#  'control',
#  'meeting',
#  'quarter',
#  'military',
#  'expected',
#  'death',
#  'study',
#  'history',
#  'increase',
#  'north',
#  'course',
#  'information',
#  'along',
#  'offer',
#  'committee',
#  'community',
#  'series',
#  'chairman',
#  'judge',
#  'nation',
#  'manhattan',
#  'different',
#  'level',
#  'march',
#  'economic',
#  'project',
#  'thought',
#  'museum',
#  'working',
#  'financial',
#  "that's",
#  'saturday',
#  'trying',
#  'close',
#  'county',
#  'avenue',
#  'budget',
#  'worker',
#  'democrat']

# %%
file = open('target words/target.txt','w')

for item in most_comon:
	file.write(item+"\n")
file.close()
